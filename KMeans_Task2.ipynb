# %%
import pandas as pd
import numpy as np

# %%
import os
print(os.path.expanduser("~"))
# Out:
# /Users/haticecakir

# %%
haticenin_verisi = pd.read_csv("/Users/haticecakir/Downloads/Veri Bilimi Dosyalar/İllere_ve_cinsiyete_göre_yaşam_süresi.csv")
haticenin_verisi
# Out:
#     Pl.Kod_Şehir  Ortalama  Erkek  Kadın
# 0              1      76.8   74.0   79.6
# 1              2      78.7   76.4   81.0
# 2              3      76.9   74.5   79.4
# 3              4      76.9   74.5   79.4
# 4              5      78.1   75.4   80.9
# ..           ...       ...    ...    ...
# 76            77      77.9   75.1   80.9
# 77            78      78.0   75.3   80.8
# 78            79      76.1   73.2   79.1
# 79            80      77.0   74.3   79.8
# 80            81      77.4   74.6   80.3
#
# [81 rows x 4 columns]

# %%
import matplotlib .pyplot as plt
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], color = "purple")
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title ("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(haticenin_verisi[['Kadın','Erkek']])
haticenin_verisi['Küme'] = kmeans.predict(haticenin_verisi[['Kadın','Erkek']])
haticenin_verisi
# Out:
#     Pl.Kod_Şehir  Ortalama  Erkek  Kadın  Küme
# 0              1      76.8   74.0   79.6     4
# 1              2      78.7   76.4   81.0     2
# 2              3      76.9   74.5   79.4     4
# 3              4      76.9   74.5   79.4     4
# 4              5      78.1   75.4   80.9     2
# ..           ...       ...    ...    ...   ...
# 76            77      77.9   75.1   80.9     2
# 77            78      78.0   75.3   80.8     2
# 78            79      76.1   73.2   79.1     4
# 79            80      77.0   74.3   79.8     4
# 80            81      77.4   74.6   80.3     0
#
# [81 rows x 5 columns]

# %%
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], c=haticenin_verisi ['Küme'])
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title ("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()

# %%
plt.scatter(haticenin_verisi["Kadın"], haticenin_verisi["Erkek"], c=haticenin_verisi ['Küme'])
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='red')
plt.xlabel("Kadın")
plt.ylabel("Erkek")
plt.title ("Cinsiyete Göre Yaşam Süresi 2021-2023")
plt.show()
